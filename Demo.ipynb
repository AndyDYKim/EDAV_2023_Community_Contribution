# %%
import geopandas as gpd 
import matplotlib.pyplot as plt
import fiona 
import numpy as np
import pandas as pd 
from shapely.geometry import LineString, Point, MultiPoint
from sklearn.cluster import DBSCAN
from geopy.distance import great_circle

# %%
# READ KML file to a geopandas dataframe 
fiona.drvsupport.supported_drivers['KML'] = 'rw'

geo_df = gpd.read_file('edav comm cont/20231029-170354 - Edav 1.kml',driver='KML')
geo_df.head()
# Out:
#                     Name                                        Description  \
# 0  Track 20231029-170354  <b>Edav 1</b><br><br>Distance = 5.16 km<br>Dur...
#
#                                             geometry
# 0  LINESTRING Z (-73.94829 40.79047 -17.13900, -7...

# %%
# Converting Shapely Lines to Points
points = [Point(coord) for coord in geo_df['geometry'].values[0].coords]
gdf = gpd.GeoDataFrame(geometry=points)
gdf.head()
# Out:
#                                  geometry
# 0  POINT Z (-73.94829 40.79047 -17.13900)
# 1  POINT Z (-73.94829 40.79046 -17.13900)
# 2  POINT Z (-73.94831 40.79045 -17.81700)
# 3  POINT Z (-73.94832 40.79046 -18.19800)
# 4  POINT Z (-73.94833 40.79047 -18.40400)

# %%
# Setting coordinate system and plotting interactive plot
gdf = gdf.set_crs('EPSG:4326')
gdf.explore(tiles='CartoDB Positron')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f1e67379dd33f6a92eec92012998bf70 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f1e67379dd33f6a92eec92012998bf70&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f1e67379dd33f6a92eec92012998bf70 = L.map(
#                 &quot;map_f1e67379dd33f6a92eec92012998bf70&quot;,
#                 {
#                     center: [40.79130411, -73.94506656],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_f1e67379dd33f6a92eec92012998bf70);
#
#
#
#
#
#             var tile_layer_3f4b47aa557cdd4ef3e38ce6252193d5 = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f1e67379dd33f6a92eec92012998bf70);
#
#
#             map_f1e67379dd33f6a92eec92012998bf70.fitBounds(
#                 [[40.78787796, -73.94921805], [40.79473026, -73.94091507]],
#                 {}
#             );
#
#
#         function geo_json_97d58ef217ab371f4f1413d4924cde23_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_97d58ef217ab371f4f1413d4924cde23_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_97d58ef217ab371f4f1413d4924cde23_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_97d58ef217ab371f4f1413d4924cde23_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_97d58ef217ab371f4f1413d4924cde23_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_97d58ef217ab371f4f1413d4924cde23.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_97d58ef217ab371f4f1413d4924cde23_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_97d58ef217ab371f4f1413d4924cde23 = L.geoJson(null, {
#                 onEachFeature: geo_json_97d58ef217ab371f4f1413d4924cde23_onEachFeature,
#
#                 style: geo_json_97d58ef217ab371f4f1413d4924cde23_styler,
#                 pointToLayer: geo_json_97d58ef217ab371f4f1413d4924cde23_pointToLayer
#         });
#
#         function geo_json_97d58ef217ab371f4f1413d4924cde23_add (data) {
#             geo_json_97d58ef217ab371f4f1413d4924cde23
#                 .addData(data)
#                 .addTo(map_f1e67379dd33f6a92eec92012998bf70);
#         }
#             geo_json_97d58ef217ab371f4f1413d4924cde23_add({&quot;bbox&quot;: [-73.94921805, 40.78787796, -73.94091507, 40.79473026], &quot;features&quot;: [{&quot;bbox&quot;: [-73.94829289, 40.79046857, -73.94829289, 40.79046857], &quot;geometry&quot;: {&quot;coordinates&quot;: [-73.94829289, 40.79046857, -17.139], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-73.94829086, 40.79046056, -73.94829086, 40.79046056], &quot;geometry&quot;: {&quot;coordinates&quot;: [-73.94829086, 40.79046056, -17.139], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox

# %%
# extracting only the latitude and longitude from shapely point
df = gdf.apply(lambda row: pd.Series({'lon': row['geometry'].x,
                                      'lat': row['geometry'].y}), 
               axis=1)

df.head()
# Out:
#          lon        lat
# 0 -73.948293  40.790469
# 1 -73.948291  40.790461
# 2 -73.948313  40.790446
# 3 -73.948324  40.790460
# 4 -73.948325  40.790468

# %%
# Calculating cluster labels for each data point
coords = np.array(df[['lat','lon']]).reshape(-1,2) 

kms_per_radian = 6371.0088
epsilon = 0.0025 / kms_per_radian

db = DBSCAN(eps=epsilon, min_samples=1, algorithm='ball_tree', metric='haversine') 
db.fit(np.radians(coords))
cluster_labels = db.labels_

num_clusters = len(set(cluster_labels))
clusters = pd.Series([coords[cluster_labels==n] for n in range(num_clusters)])
print('Number of clusters: {}'.format(num_clusters))
# Out:
# Number of clusters: 318

# %%
# finding the closest datapoint to the cluster's center
def get_centermost_point(cluster):
    centroid = (MultiPoint(cluster).centroid.x, MultiPoint(cluster).centroid.y)
    centermost_point = min(cluster, key=lambda point: great_circle(point, centroid).m)
    return tuple(centermost_point)
centermost_points = clusters.map(get_centermost_point)

# %%
# filtering out datapoints from original dataframe that is closest to cluster center
lats, lons = zip(*centermost_points)
rep_points = pd.DataFrame({'lon':lons, 'lat':lats})

rs = rep_points.apply(lambda row: df[(df['lat']==row['lat']) &
                                     (df['lon']==row['lon'])].iloc[0], 
                      axis=1)
rs
# Out:
#            lon        lat
# 0   -73.948431  40.790478
# 1   -73.948220  40.790464
# 2   -73.948177  40.790443
# 3   -73.948449  40.790416
# 4   -73.948619  40.790364
# ..         ...        ...
# 313 -73.948851  40.790563
# 314 -73.948764  40.790637
# 315 -73.948675  40.790531
# 316 -73.948423  40.790401
# 317 -73.948325  40.790356
#
# [318 rows x 2 columns]

# %%
# Converting the coordinates to shapely points to create geodataframe for plotting
geometry = [Point(lon, lat) for lon, lat in zip(rs['lon'], rs['lat'])]
gdf_small = gpd.GeoDataFrame(rs, geometry=geometry)
gdf_small.head()
# Out:
#          lon        lat                    geometry
# 0 -73.948431  40.790478  POINT (-73.94843 40.79048)
# 1 -73.948220  40.790464  POINT (-73.94822 40.79046)
# 2 -73.948177  40.790443  POINT (-73.94818 40.79044)
# 3 -73.948449  40.790416  POINT (-73.94845 40.79042)
# 4 -73.948619  40.790364  POINT (-73.94862 40.79036)

# %%
# Setting coordinate system to map points onto and plotting interactive plot
gdf_small = gdf_small.set_crs('EPSG:4326')
gdf_small.explore(tiles='CartoDB Positron')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_263cce0d50340e3927bb7f59f9e3b19d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_263cce0d50340e3927bb7f59f9e3b19d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_263cce0d50340e3927bb7f59f9e3b19d = L.map(
#                 &quot;map_263cce0d50340e3927bb7f59f9e3b19d&quot;,
#                 {
#                     center: [40.79128016, -73.94505754],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_263cce0d50340e3927bb7f59f9e3b19d);
#
#
#
#
#
#             var tile_layer_3fcb0ba9498be4c457f5f895bcf164fe = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_263cce0d50340e3927bb7f59f9e3b19d);
#
#
#             map_263cce0d50340e3927bb7f59f9e3b19d.fitBounds(
#                 [[40.78787978, -73.94917086], [40.79468054, -73.94094422]],
#                 {}
#             );
#
#
#         function geo_json_3b0e0c6bf3d67d66420d71ba9cd27aeb_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_3b0e0c6bf3d67d66420d71ba9cd27aeb_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_3b0e0c6bf3d67d66420d71ba9cd27aeb_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_3b0e0c6bf3d67d66420d71ba9cd27aeb_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_3b0e0c6bf3d67d66420d71ba9cd27aeb_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_3b0e0c6bf3d67d66420d71ba9cd27aeb.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_3b0e0c6bf3d67d66420d71ba9cd27aeb_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_3b0e0c6bf3d67d66420d71ba9cd27aeb = L.geoJson(null, {
#                 onEachFeature: geo_json_3b0e0c6bf3d67d66420d71ba9cd27aeb_onEachFeature,
#
#                 style: geo_json_3b0e0c6bf3d67d66420d71ba9cd27aeb_styler,
#                 pointToLayer: geo_json_3b0e0c6bf3d67d66420d71ba9cd27aeb_pointToLayer
#         });
#
#         function geo_json_3b0e0c6bf3d67d66420d71ba9cd27aeb_add (data) {
#             geo_json_3b0e0c6bf3d67d66420d71ba9cd27aeb
#                 .addData(data)
#                 .addTo(map_263cce0d50340e3927bb7f59f9e3b19d);
#         }
#             geo_json_3b0e0c6bf3d67d66420d71ba9cd27aeb_add({&quot;bbox&quot;: [-73.94917086, 40.78787978, -73.94094422, 40.79468054], &quot;features&quot;: [{&quot;bbox&quot;: [-73.94843098, 40.79047753, -73.94843098, 40.79047753], &quot;geometry&quot;: {&quot;coordinates&quot;: [-73.94843098, 40.79047753], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;lat&quot;: 40.79047753, &quot;lon&quot;: -73.94843098}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-73.94821969, 40.79046449, -73.94821969, 40.79046449], &quot;geometry&quot;: {&quot;coordinates&quot;: [-73.94821969, 40.79046449], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;lat&quo
